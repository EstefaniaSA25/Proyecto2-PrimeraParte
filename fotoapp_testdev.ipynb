# %% [markdown]
# # ***PREPARANDO EL ENTORNO PARA EL PROYECTO***

# %% [markdown]
# ## Instalando librerias necesarias

# %%
# !pip install pillow matplotlib opencv-python numpy requests

# %% [markdown]
# ### Importando modulos necesarios para el proyecto

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.pyplot as plt
import cv2 # es el modulo de open cv biblioteca para procesamiento de imgenes
import numpy as np
# Para visualizar en Colab
from google.colab.patches import cv2_imshow # cv.imshow

# %% [markdown]
# ## Importando funciones desde el módulo fotoapp

# %%
from fotoapp import redimensionar_imagen, aplicar_filtro, ajustar_contraste, crear_boceto, menu_principal

# %% [markdown]
# # ***PRIMERA PARTE***

# %% [markdown]
# ### **PRUEBA 1: Redimensionar imagen**

# %%
ruta = "https://cdn.pixabay.com/photo/2012/12/19/18/13/flowers-70970_1280.jpg"

# %%
redimensionar_imagen(ruta, "youtube")

# %%
redimensionar_imagen(ruta, "Instagram")

# %% [markdown]
# ### **PRUEBA 2: Ajustar contraste (ecualización)**

# %%
# Foto algo oscura
ruta_oscura = "https://crehana-blog.imgix.net/media/filer_public/29/e8/29e8add6-e0a9-44d3-b7f5-a13a4ed4b219/como_aclarar_una_foto_oscura.jpg?auto=format&q=45&w=1440&h=auto&fit=crop"

ajustar_contraste(ruta_oscura, "oscura")

# %%
# Foto con exceso de luz
ruta_brillante = "https://factoriacultural.es/wp-content/uploads/2021/09/mujer-exceso-luz-natural-persiana-1140x570.jpg"

ajustar_contraste(ruta_brillante, "brillante")

# %% [markdown]
# ### **PRUEBA 3: Aplicar filtros de Pillow**

# %%
ruta = "https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https://substack-post-media.s3.amazonaws.com/public/images/083be2c9-0e33-47b8-8bd9-42ba599ac7be_1280x720.png"
filtro_elegido = "contour"


img_filtrada = aplicar_filtro(ruta, filtro_elegido)

# %% [markdown]
# ### **PRUEBA 4: Crear boceto para pintores**

# %%
# Imagen de ejemplo
ruta_persona = "https://www.revistaclase.mx/sites/default/files/imagenes_especiales/4bellas.jpg"

# Probar ambos modos
crear_boceto(ruta_persona, modo="bordes")

crear_boceto(ruta_persona, modo="lapiz")

# %% [markdown]
# ### **PRUEBA 5: Menú interactivo**

# %%
menu_principal()
